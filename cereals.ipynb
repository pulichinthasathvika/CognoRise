# %% [markdown]
# ### Task - 2

# %% [markdown]
# ### 80 CEREALS

# %% [markdown]
# If you like to eat cereal, do yourself a favor and avoid this dataset at all costs.
# After seeing these data it will never be the same for me to eat Fruity Pebbles
# again.
#
# • Do an explained data analysis

# %% [markdown]
# • <b> Name: Name of cereal </b>
#
# mfr: Manufacturer of cereal
#
# A = American Home Food Products;
#
# G = General Mills
#
# K = Kelloggs
#
# N = Nabisco
#
# P = Post
#
# Q = Quaker Oats
#
# R = Ralston Purina
#
# • <b> type: </b>
#
# cold
#
# hot
#
# • calories: calories per serving
#
# • protein: grams of protein
#
# • fat: grams of fat
#
# • sodium: milligrams of sodium
#
# • fiber: grams of dietary fiber
#
# • carbo: grams of complex carbohydrates
#
# • sugars: grams of sugars
#
# • potass: milligrams of potassium
#
# • vitamins: vitamins and minerals - 0, 25, or 100, indicating the typical percentage of FDA recommended
#
# • shelf: display shelf (1, 2, or 3, counting from the floor)
#
# • weight: weight in ounces of one serving
#
# • cups: number of cups in one serving
#
# • rating: a rating of the cereals (Possibly from Consumer Reports?)

# %% [markdown]
# ### importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### data

# %%
cereals=pd.read_csv("cereal.csv")

# %%
cereals.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %% [markdown]
# ### shape

# %%
cereals.shape
# Out:
# (77, 16)

# %%
cereals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
cereals['mfr'] = cereals['mfr'].replace({ 'A':'American Home Food Products','G':'General Mills','K':'Kelloggs','N':'Nabisco','P':'Post','Q':'Quaker Oats','R':'Ralston Purina'})

cereals['type'] = cereals['type'].replace({'C':'Cold','H':'Hot'})

# %%
cereals.head()
# Out:
#                         name             mfr  type  calories  protein  fat  \
# 0                  100% Bran         Nabisco  Cold        70        4    1
# 1          100% Natural Bran     Quaker Oats  Cold       120        3    5
# 2                   All-Bran        Kelloggs  Cold        70        4    1
# 3  All-Bran with Extra Fiber        Kelloggs  Cold        50        4    0
# 4             Almond Delight  Ralston Purina  Cold       110        2    2
#
#    sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 0     130   10.0    5.0       6     280        25      3     1.0  0.33
# 1      15    2.0    8.0       8     135         0      3     1.0  1.00
# 2     260    9.0    7.0       5     320        25      3     1.0  0.33
# 3     140   14.0    8.0       0     330        25      3     1.0  0.50
# 4     200    1.0   14.0       8      -1        25      3     1.0  0.75
#
#       rating
# 0  68.402973
# 1  33.983679
# 2  59.425505
# 3  93.704912
# 4  34.384843

# %%
cereals["shelf"]= cereals["shelf"].astype(object)
cereals["vitamins"]=cereals["vitamins"].astype(object)
cereals["protein"]=cereals["protein"].astype(object)
cereals["fat"]=cereals["fat"].astype(object)

# %%
cereals["fat"].value_counts()
# Out:
# 1    30
# 0    27
# 2    14
# 3     5
# 5     1
# Name: fat, dtype: int64

# %% [markdown]
# ### Analysis on Categorical columns

# %%
def discrete_univariate_analysis(discrete_data):
    for col_name in discrete_data:
        print("*"*10, col_name, "*"*10)
        print(discrete_data[col_name].agg(['count', 'nunique', 'unique']))
        print('Value Counts: \n', discrete_data[col_name].value_counts())
        print()

# %%
discrete_df = cereals.select_dtypes(include=['object'])
discrete_univariate_analysis(discrete_df)
# Out:
# ********** name **********
# count                                                     77
# nunique                                                   77
# unique     [100% Bran, 100% Natural Bran, All-Bran, All-B...
# Name: name, dtype: object
# Value Counts:
#  100% Bran                    1
# Nutri-Grain Almond-Raisin    1
# Quaker Oat Squares           1
# Puffed Wheat                 1
# Puffed Rice                  1
#                             ..
# Frosted Flakes               1
# Froot Loops                  1
# Double Chex                  1
# Crispy Wheat & Raisins       1
# Wheaties Honey Gold          1
# Name: name, Length: 77, dtype: int64
#
# ********** mfr **********
# count                                                     77
# nunique                                                    7
# unique     [Nabisco, Quaker Oats, Kelloggs, Ralston Purin...
# Name: mfr, dtype: object
# Value Counts:
#  Kelloggs                       23
# General Mills                  22
# ...

# %% [markdown]
# ### Analysis on numerical data

# %%
def numerical_univariate_analysis(numerical_data):
    for col_name in numerical_data:
        print("*"*10, col_name, "*"*10)
        print(numerical_data[col_name].agg(['count', 'min', 'max', 'mean', 'median', 'std', 'skew']))
        print()

# %%
numerical_df =cereals.select_dtypes(include=['float64','int64'])
numerical_univariate_analysis(numerical_df)
# Out:
# ********** calories **********
# count      77.000000
# min        50.000000
# max       160.000000
# mean      106.883117
# median    110.000000
# std        19.484119
# skew       -0.445407
# Name: calories, dtype: float64
#
# ********** sodium **********
# count      77.000000
# min         0.000000
# max       320.000000
# mean      159.675325
# median    180.000000
# std        83.832295
# skew       -0.575711
# Name: sodium, dtype: float64
#
# ********** fiber **********
# count     77.000000
# min        0.000000
# max       14.000000
# mean       2.151948
# median     2.000000
# std        2.383364
# skew       2.431675
# Name: fiber, dtype: float64
#
# ********** carbo **********
# count     77.000000
# min       -1.000000
# max       23.000000
# mean      14.597403
# median    14.000000
# std        4.278956
# skew      -0.447929
# Name: carbo, dtype: float64
#
# ********** sugars **********
# count     77.000000
# min       -1.000000
# max       15.000000
# ...

# %%
corr = cereals.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=True, cmap="Purples")
plt.show()
# Out:
# C:\Users\sathv\AppData\Local\Temp\ipykernel_2960\57968493.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = cereals.corr()

# %% [markdown]
# ### Visual Analysis on categorical data

# %%
fig,axs = plt.subplots(figsize=(13,3),layout="constrained")
sns.countplot(data=cereals,x='mfr',ax=axs)
# Out:
# <Axes: xlabel='mfr', ylabel='count'>

# %%
fig,axs = plt.subplots(figsize=(5,3),layout="constrained")
sns.countplot(data=cereals,x='type',ax=axs)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
fig,axs=plt.subplots(1,2,figsize=(9,7),layout="constrained")
p=cereals["mfr"].value_counts()
axs[0].pie(p.values,labels=p.index,autopct="%1.1f%%")
q=cereals["type"].value_counts()
axs[1].pie(q.values,labels=q.index,autopct="%1.1f%%")
plt.show()

# %% [markdown]
# ### Visual Analysis on categorial v/s numerical

# %%
fig, axs = plt.subplots(1, 5, figsize=(10, 3), constrained_layout=True)

sns.boxplot(data=cereals, x="shelf", y="calories", ax=axs[0])
sns.boxplot(data=cereals, x="shelf", y="sodium", ax=axs[1])
sns.boxplot(data=cereals, x="shelf", y="potass", ax=axs[2])
sns.boxplot(data=cereals, x="shelf", y="sugars", ax=axs[3])
sns.boxplot(data=cereals, x="shelf", y="fiber", ax=axs[4])
# Out:
# <Axes: xlabel='shelf', ylabel='fiber'>

# %%
fig, axs = plt.subplots(1, 5, figsize=(10, 3), constrained_layout=True)

sns.boxplot(data=cereals, x="vitamins", y="calories", ax=axs[0])
sns.boxplot(data=cereals, x="vitamins", y="sodium", ax=axs[1])
sns.boxplot(data=cereals, x="vitamins", y="potass", ax=axs[2])
sns.boxplot(data=cereals, x="vitamins", y="sugars", ax=axs[3])
sns.boxplot(data=cereals, x="vitamins", y="fiber", ax=axs[4])
# Out:
# <Axes: xlabel='vitamins', ylabel='fiber'>

# %%
fig, axs = plt.subplots(1, 5, figsize=(10, 3), constrained_layout=True)

sns.boxplot(data=cereals, x="protein", y="calories", ax=axs[0])
sns.boxplot(data=cereals, x="protein", y="sodium", ax=axs[1])
sns.boxplot(data=cereals, x="protein", y="potass", ax=axs[2])
sns.boxplot(data=cereals, x="protein", y="sugars", ax=axs[3])
sns.boxplot(data=cereals, x="protein", y="fiber", ax=axs[4])
# Out:
# <Axes: xlabel='protein', ylabel='fiber'>

# %%
fig, axs = plt.subplots(1, 5, figsize=(12, 3), constrained_layout=True)

sns.boxplot(data=cereals, x="fat", y="calories", ax=axs[0])
sns.boxplot(data=cereals, x="fat", y="sodium", ax=axs[1])
sns.boxplot(data=cereals, x="fat", y="potass", ax=axs[2])
sns.boxplot(data=cereals, x="fat", y="sugars", ax=axs[3])
sns.boxplot(data=cereals, x="fat", y="fiber", ax=axs[4])
# Out:
# <Axes: xlabel='fat', ylabel='fiber'>

# %% [markdown]
# ### Distribution of Rating

# %%
plt.hist(cereals["rating"], edgecolor="blue")
plt.title("Distribution of Rating")
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.show()

# %%
fig,axs=plt.subplots(1,3,figsize=(10,3),layout="constrained")
sns.scatterplot(data=cereals,x="rating",y="sodium",hue="type",ax=axs[0])
sns.scatterplot(data=cereals,x="rating",y="fiber",hue="type",ax=axs[1])
sns.scatterplot(data=cereals,x="rating",y="potass",hue="type",ax=axs[2])
# Out:
# <Axes: xlabel='rating', ylabel='potass'>
